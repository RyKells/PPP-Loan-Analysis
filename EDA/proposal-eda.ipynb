# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
plt.style.use('fivethirtyeight')

# %%
df_o150 = pd.read_csv('/Users/rykells/Documents/Capstone-1-Data/All-Data-by-State/150k-plus/PPP-Data-150k-plus.csv')
df_u150_CO = pd.read_csv('/Users/rykells/Documents/Capstone-1-Data/All-Data-by-State/Colorado/PPP-Data-up-to-150k-CO.csv')

# %%
df_o150.shape
# Out:
# (661218, 16)

# %%
df_o150.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661218 entries, 0 to 661217
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   LoanRange      661218 non-null  object
#  1   BusinessName   661210 non-null  object
#  2   Address        661201 non-null  object
#  3   City           661203 non-null  object
#  4   State          661218 non-null  object
#  5   Zip            661202 non-null  float64
#  6   NAICSCode      654435 non-null  float64
#  7   BusinessType   659789 non-null  object
#  8   RaceEthnicity  661218 non-null  object
#  9   Gender         661218 non-null  object
#  10  Veteran        661218 non-null  object
#  11  NonProfit      42462 non-null   object
#  12  JobsRetained   620712 non-null  float64
#  13  DateApproved   661218 non-null  object
#  14  Lender         661218 non-null  object
#  15  CD             661218 non-null  object
# dtypes: float64(3), object(13)
# ...

# %%
df_u150_CO.shape
# Out:
# (91018, 14)

# %%
df_o150.columns
# Out:
# Index(['LoanRange', 'BusinessName', 'Address', 'City', 'State', 'Zip',
#        'NAICSCode', 'BusinessType', 'RaceEthnicity', 'Gender', 'Veteran',
#        'NonProfit', 'JobsRetained', 'DateApproved', 'Lender', 'CD'],
#       dtype='object')

# %%
df_u150_CO.columns
# Out:
# Index(['LoanAmount', 'City', 'State', 'Zip', 'NAICSCode', 'BusinessType',
#        'RaceEthnicity', 'Gender', 'Veteran', 'NonProfit', 'JobsRetained',
#        'DateApproved', 'Lender', 'CD'],
#       dtype='object')

# %%
df_u150_CO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91018 entries, 0 to 91017
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LoanAmount     91018 non-null  float64
#  1   City           91017 non-null  object
#  2   State          91018 non-null  object
#  3   Zip            91017 non-null  float64
#  4   NAICSCode      88767 non-null  float64
#  5   BusinessType   90949 non-null  object
#  6   RaceEthnicity  91018 non-null  object
#  7   Gender         91018 non-null  object
#  8   Veteran        91018 non-null  object
#  9   NonProfit      3016 non-null   object
#  10  JobsRetained   82822 non-null  float64
#  11  DateApproved   91018 non-null  object
#  12  Lender         91018 non-null  object
#  13  CD             91018 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 9.7+ MB

# %%
df_o150.columns
# Out:
# Index(['LoanRange', 'BusinessName', 'Address', 'City', 'State', 'Zip',
#        'NAICSCode', 'BusinessType', 'RaceEthnicity', 'Gender', 'Veteran',
#        'NonProfit', 'JobsRetained', 'DateApproved', 'Lender', 'CD'],
#       dtype='object')

# %%
df_o150['LoanRange'].unique()
# Out:
# array(['a $5-10 million', 'b $2-5 million', 'c $1-2 million',
#        'd $350,000-1 million', 'e $150,000-350,000'], dtype=object)

# %%
df_o150['LoanRange'].hist()

# %%
plt.hist(df_o150['LoanRange'])
plt.labels('$5-10 million','$2-5 million', '$1-2')
# Out:
# (array([  4840.,      0.,  24838.,      0.,      0.,  53030.,      0.,
#         199456.,      0., 379054.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
df_u150_CO['LoanAmount'].hist()

# %%
fig, ax = plt.subplots(figsize=(12,9))

ax.hist(df_u150_CO['LoanAmount'], bins = 10, color='red')
plt.title('Distribution of PPP Loans in CO under $150k')
ax.set_xlim(min(0),max(150000))
fmt = 'S{x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
plt.xlabel.set_major_formatter(tick)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e7200b6393d> in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(12,9))
#       2
#       3 ax.hist(df_u150_CO['LoanAmount'], bins = 10, color='red')
#       4 plt.title('Distribution of PPP Loans in CO under $150k')
#       5 ax.set_xlim(min(0),max(150000))
#
# NameError: name 'plt' is not defined

# %%
df_o150["LoanRange"]
# Out:
# 0            a $5-10 million
# 1            a $5-10 million
# 2            a $5-10 million
# 3            a $5-10 million
# 4            a $5-10 million
#                  ...
# 661213    e $150,000-350,000
# 661214    e $150,000-350,000
# 661215    e $150,000-350,000
# 661216    e $150,000-350,000
# 661217    e $150,000-350,000
# Name: LoanRange, Length: 661218, dtype: object

# %%
df_o150['Adj_Loan_Range'] = [t[2:] for t in df_o150['LoanRange']]

# %%
df_o150.head()
# Out:
#          LoanRange                           BusinessName  \
# 0  a $5-10 million  ARCTIC SLOPE NATIVE ASSOCIATION, LTD.
# 1  a $5-10 million                  CRUZ CONSTRUCTION INC
# 2  a $5-10 million                 I. C. E. SERVICES, INC
# 3  a $5-10 million             KATMAI HEALTH SERVICES LLC
# 4  a $5-10 million        MATANUSKA TELEPHONE ASSOCIATION
#
#                                   Address       City State      Zip  \
# 0                            7000 Uula St     BARROW    AK  99723.0
# 1            7000 East Palmer Wasilla Hwy     PALMER    AK  99645.0
# 2                           2606 C Street  ANCHORAGE    AK  99503.0
# 3  11001 O'MALLEY CENTRE DRIVE, SUITE 204  ANCHORAGE    AK  99515.0
# 4                      1740 S. CHUGACH ST     PALMER    AK  99645.0
#
#    NAICSCode                     BusinessType RaceEthnicity      Gender  \
# 0   813920.0          Non-Profit Organization    Unanswered  Unanswered
# ...

# %%
plt.hist(df_o150['Adj_Loan_Range'])
# Out:
# (array([  4840.,      0.,  24838.,      0.,      0.,  53030.,      0.,
#         199456.,      0., 379054.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x=df_u150_CO['LoanAmount'],y=df_u150_CO['JobsRetained'])
plt.title('PPP Loans Under $150k CO')
plt.xlabel('Loan Amount')
plt.ylabel('Jobs Retained')
plt.savefig('PPP_CO_U150_LA_vs_JR.png')

# %%
plt.hist(df_u150_CO['LoanAmount'])
plt.title('PPP Loans Under $150k CO')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df_o150['LoanRange'].unique()
# Out:
# array(['a $5-10 million', 'b $2-5 million', 'c $1-2 million',
#        'd $350,000-1 million', 'e $150,000-350,000'], dtype=object)
